# %% [markdown]
# # IDB_drilling_signal

# %% [markdown]
# ## Import packages

# %%
import IPython
import librosa
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import scipy.io as scio
import seaborn as sns
import time
import visualkeras

from keras.layers import Activation, BatchNormalization, Concatenate, Conv1D, Conv2D, Dense, Dropout, Flatten, GlobalAveragePooling1D, GlobalAveragePooling2D, Input, MaxPooling1D, MaxPooling2D
from keras.models import load_model, Model, Sequential
from keras.utils.np_utils import to_categorical
from pyts.image import RecurrencePlot, MarkovTransitionField, GramianAngularField
from tensorflow import keras
from tqdm import tqdm

# import xgboost as xgb
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# !nvidia-smi

HOST_path = "/hpctmp/e1097232"

random.seed(42)

def nameof(var):
    for name, value in globals().items():
        if value is var:
            return name
# Out:
# Mon Jul  3 16:50:43 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-32GB            Off| 00000000:1D:00.0 Off |                    0 |
# | N/A   33C    P0               42W / 300W|      0MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Load signal data

# %%
RATE = 8192

def read_matFile(signal_path):
    signal_file = scio.loadmat(signal_path)
    signal_value = signal_file['samples']
    signal_value = np.squeeze(signal_value)
    print("signal_shape:", signal_value.shape, "sampling_rate:", RATE, "time:", len(signal_value)/RATE, "s")
    max_value = np.max(np.abs(signal_value))
    signal_value_normalized = signal_value / max_value
    return signal_value_normalized

def read_allFile(signal_path):
    signal_value, signal_rate = librosa.load(signal_path, sr=None, mono=True, offset=0.0, duration=None)
    print("signal_shape:", signal_value.shape, "sampling_rate:", signal_rate, "time:", len(signal_value)/signal_rate, "s")
    if signal_rate != RATE:
        signal_value = librosa.resample(signal_value, orig_sr=signal_rate, target_sr=RATE)
    max_value = np.max(np.abs(signal_value))
    signal_value_normalized = signal_value / max_value
    return signal_value_normalized

# granite
G32h = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment1/matFile/3-2h.mat"))
G41h = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment1/matFile/4-1h.mat"))
G42h = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment1/matFile/4-2h.mat"))
G43b = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment1/matFile/4-3b.mat"))
# sandstone
S11 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/1-1.mat"))
S12 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/1-2.mat"))
S13 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/1-3.mat"))
S14 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/1-4.mat"))
S21 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/2-1.mat"))
S22 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/2-2.mat"))
S23 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/2-3.mat"))
S31 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/3-1.mat"))
S32 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/3-2.mat"))
S33 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/3-3.mat"))
S41 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/4-1.mat"))
S42 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/4-2.mat"))
S43 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/4-3.mat"))
S51 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/5-1.mat"))
S52 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/5-2.mat"))
S53 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/5-3.mat"))
S54 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/5-4.mat"))
S61 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/6-1.mat"))
S62 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/6-2.mat"))
S63 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/6-3.mat"))
S71 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/7-1.mat"))
S72 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/7-2.mat"))
S73 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/7-3.mat"))
S74 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/7-4.mat"))
S81 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/8-1.mat"))
S82 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/8-2.mat"))
S83 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/8-3.mat"))
S91 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/9-1.mat"))
S92 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/9-2.mat"))
S93 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/9-3.mat"))
S94 = read_matFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment2/matFile/9-4.mat"))
# basalt
B11 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/1-1.wav"))
B12 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/1-2.wav"))
B13 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/1-3.wav"))
B21 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/2-1.wav"))
B22 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/2-2.wav"))
B23 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/2-3.wav"))
B31 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/3-1.wav"))
B32 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/3-2.wav"))
B33 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/3-3.wav"))
B41 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/4-1.wav"))
B42 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/4-2.wav"))
B43 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/4-3.wav"))
B51 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/5-1.wav"))
B52 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/5-2.wav"))
B53 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/5-3.wav"))
B54 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/5-4.wav"))
B61 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/6-1.wav"))
B62 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/6-2.wav"))
B63 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/6-3.wav"))
B71 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/7-1.wav"))
B72 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/7-2.wav"))
B73 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/7-3.wav"))
B81 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/8-1.wav"))
B82 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/8-2.wav"))
B83 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/8-3.wav"))
B91 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/9-1.wav"))
B92 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/9-2.wav"))
B93 = read_allFile(os.path.join(HOST_path, "IDB_drilling_signal/Rock_drilling_signal/experiment3/waveFile/9-3.wav"))
print("------------------------------------")
print("All signal normalized with sr = 8192")
# Out:
# signal_shape: (8880128,) sampling_rate: 8192 time: 1084.0 s
# signal_shape: (7216896,) sampling_rate: 8192 time: 880.96875 s
# signal_shape: (11019776,) sampling_rate: 8192 time: 1345.1875 s
# signal_shape: (22244352,) sampling_rate: 8192 time: 2715.375 s
# signal_shape: (1248512,) sampling_rate: 8192 time: 152.40625 s
# signal_shape: (3898112,) sampling_rate: 8192 time: 475.84375 s
# signal_shape: (3248384,) sampling_rate: 8192 time: 396.53125 s
# signal_shape: (1114368,) sampling_rate: 8192 time: 136.03125 s
# signal_shape: (846336,) sampling_rate: 8192 time: 103.3125 s
# signal_shape: (1461248,) sampling_rate: 8192 time: 178.375 s
# signal_shape: (1584384,) sampling_rate: 8192 time: 193.40625 s
# signal_shape: (727296,) sampling_rate: 8192 time: 88.78125 s
# signal_shape: (1953536,) sampling_rate: 8192 time: 238.46875 s
# signal_shape: (1200384,) sampling_rate: 8192 time: 146.53125 s
# signal_shape: (354560,) sampling_rate: 8192 time: 43.28125 s
# signal_shape: (1647872,) sampling_rate: 8192 time: 201.15625 s
# signal_shape: (1210112,) sampling_rate: 8192 time: 147.71875 s
# signal_shape: (268288,) sampling_rate: 8192 time: 32.75 s
# signal_shape: (1660672,) sampling_rate: 8192 time: 202.71875 s
# signal_shape: (1528320,) sampling_rate: 8192 time: 186.5625 s
# signal_shape: (1656064,) sampling_rate: 8192 time: 202.15625 s
# signal_shape: (499456,) sampling_rate: 8192 time: 60.96875 s
# signal_shape: (1328384,) sampling_rate: 8192 time: 162.15625 s
# signal_shape: (567808,) sampling_rate: 8192 time: 69.3125 s
# signal_shape: (736256,) sampling_rate: 8192 time: 89.875 s
# signal_shape: (5101056,) sampling_rate: 8192 time: 622.6875 s
# signal_shape: (2409984,) sampling_rate: 8192 time: 294.1875 s
# signal_shape: (2437376,) sampling_rate: 8192 time: 297.53125 s
# signal_shape: (642048,) sampling_rate: 8192 time: 78.375 s
# signal_shape: (1749248,) sampling_rate: 8192 time: 213.53125 s
# signal_shape: (2945792,) sampling_rate: 8192 time: 359.59375 s
# signal_shape: (439040,) sampling_rate: 8192 time: 53.59375 s
# signal_shape: (1120768,) sampling_rate: 8192 time: 136.8125 s
# signal_shape: (2563840,) sampling_rate: 8192 time: 312.96875 s
# signal_shape: (4210688,) sampling_rate: 8192 time: 514.0 s
# signal_shape: (7873872,) sampling_rate: 16000 time: 492.117 s
# signal_shape: (6624933,) sampling_rate: 16000 time: 414.0583125 s
# signal_shape: (4497957,) sampling_rate: 16000 time: 281.1223125 s
# signal_shape: (2840912,) sampling_rate: 16000 time: 177.557 s
# signal_shape: (2931706,) sampling_rate: 16000 time: 183.231625 s
# signal_shape: (2897914,) sampling_rate: 16000 time: 181.119625 s
# signal_shape: (2771962,) sampling_rate: 16000 time: 173.247625 s
# signal_shape: (4343802,) sampling_rate: 16000 time: 271.487625 s
# signal_shape: (2998266,) sampling_rate: 16000 time: 187.391625 s
# signal_shape: (1757861,) sampling_rate: 16000 time: 109.8663125 s
# signal_shape: (1036965,) sampling_rate: 16000 time: 64.8103125 s
# signal_shape: (1489232,) sampling_rate: 16000 time: 93.077 s
# signal_shape: (1429157,) sampling_rate: 16000 time: 89.3223125 s
# signal_shape: (4470778,) sampling_rate: 16000 time: 279.423625 s
# signal_shape: (1995770,) sampling_rate: 16000 time: 124.735625 s
# signal_shape: (1989968,) sampling_rate: 16000 time: 124.373 s
# signal_shape: (3490810,) sampling_rate: 16000 time: 218.175625 s
# signal_shape: (2688677,) sampling_rate: 16000 time: 168.0423125 s
# signal_shape: (2135717,) sampling_rate: 16000 time: 133.4823125 s
# signal_shape: (4740773,) sampling_rate: 16000 time: 296.2983125 s
# signal_shape: (3441317,) sampling_rate: 16000 time: 215.0823125 s
# signal_shape: (4853764,) sampling_rate: 16000 time: 303.36025 s
# signal_shape: (2920101,) sampling_rate: 16000 time: 182.5063125 s
# signal_shape: (2929658,) sampling_rate: 16000 time: 183.103625 s
# signal_shape: (3593552,) sampling_rate: 16000 time: 224.597 s
# signal_shape: (3216720,) sampling_rate: 16000 time: 201.045 s
# signal_shape: (2543952,) sampling_rate: 16000 time: 158.997 s
# signal_shape: (2620045,) sampling_rate: 16000 time: 163.7528125 s
# ------------------------------------
# All signal normalized with sr = 8192

# %% [markdown]
# ## Plot signal data

# %%
def displayWaveform(signal, rate):
  plt.figure(figsize=(20,6))
  max = np.max(np.absolute(signal))*1.2
  time = np.arange(0, len(SIGNAL)) / RATE
  plt.plot(time, signal)
  plt.title("Time domain waveform of speech signal")
  plt.xlabel("time (s)")
  plt.ylabel("amplitude")
  plt.xlim(0,len(SIGNAL)/RATE)
  ymin, ymax = plt.ylim()
  ylim = np.maximum(np.abs(ymin), np.abs(ymax))
  plt.ylim(-ylim, ylim)

def displaySpectrum(signal, rate):
  plt.figure(figsize=(20,6)) 
  s = np.fft.fft(signal)
  m = np.abs(s)
  n = len(signal)
  f = np.fft.fftfreq(n, 1/rate)
  plt.plot(f[:n//2],m[:n//2])
  plt.title("Frequency domain spectral line of speech signal")
  plt.xlabel("Frequency (Hz)")
  plt.ylabel("amplitude")
  plt.xlim(0, rate//2)

def displaySpectrogram(signal, rate, fftlen):    
  plt.figure(figsize=(8,6))
  plt.specgram(signal, NFFT=fftlen, Fs=rate, noverlap=int(fftlen*0.25), window=np.hanning(fftlen))
  plt.title('Linear-frequency power spectrogram')
  plt.xlabel('time (s)')
  plt.ylabel('Frequency (Hz)')
  plt.colorbar(format="%+2.0f dB")
    
def displayMelspectrogram(signal, rate):
  plt.figure(figsize=(8,6))
  # melspectrogram = librosa.feature.melspectrogram(y=signal, sr=rate)
  D = np.abs(librosa.stft(signal))**2
  S = librosa.feature.melspectrogram(S=D, sr=rate)
  S_dB = librosa.power_to_db(S, ref=np.max)
  img = librosa.display.specshow(S_dB, sr=rate, fmax=rate/2, x_axis='time', y_axis='mel') 
  plt.title('Mel-frequency spectrogram')
  plt.colorbar(format='%+2.0f dB')

def diaplayMFCC(signal, rate):
  plt.figure(figsize=(8,6))
  mfccs = librosa.feature.mfcc(y=signal, sr=rate)
  librosa.display.specshow(mfccs, sr=rate, x_axis='time')
  plt.colorbar(format='%+2.0f dB')

def displayZCR(signal, rate):
  plt.figure(figsize=(8,3))
  zcrs = librosa.feature.zero_crossing_rate(signal)  
  plt.plot(zcrs[0])

def normalize(x, axis=0):
    return preprocessing.minmax_scale(x, axis=axis)

def displayCentroids(signal, rate):
  cent = librosa.feature.spectral_centroid(y=signal, sr=rate) 
  S, phase = librosa.magphase(librosa.stft(y=signal))
  S_db = librosa.amplitude_to_db(S, ref=np.max)
  librosa.feature.spectral_centroid(S=S)
  freqs, times, D = librosa.reassigned_spectrogram(signal, fill_nan=True)
  librosa.feature.spectral_centroid(S=np.abs(D), freq=freqs)
  times = librosa.times_like(cent)
  fig, ax = plt.subplots(nrows=2, sharex=True)
  ax[0].semilogy(times, cent[0], label='Spectral centroid')
  ax[0].set(ylabel='Hz', xticks=[], xlim=[times.min(), times.max()])
  ax[0].legend()
  ax[0].label_outer()
  librosa.display.specshow(S_db, x_axis='time', y_axis='log', ax=ax[1])
  ax[1].plot(times, cent.T, label='Spectral centroid', color='w')
  ax[1].set(title='log Power spectrogram')
  ax[1].legend(loc='lower right')

def displayBandwidth(signal, rate):
  spec_bw = librosa.feature.spectral_bandwidth(y=signal, sr=rate)
  S, phase = librosa.magphase(librosa.stft(y=signal))
  S_db = librosa.amplitude_to_db(S, ref=np.max)
  librosa.feature.spectral_bandwidth(S=S)
  freqs, times, D = librosa.reassigned_spectrogram(signal, fill_nan=True)
  librosa.feature.spectral_bandwidth(S=np.abs(D), freq=freqs)
  times = librosa.times_like(spec_bw)
  centroid = librosa.feature.spectral_centroid(S=S)
  fig, ax = plt.subplots(nrows=2, sharex=True)
  ax[0].semilogy(times, spec_bw[0], label='Spectral bandwidth')
  ax[0].set(ylabel='Hz', xticks=[], xlim=[times.min(), times.max()])
  ax[0].legend()
  ax[0].label_outer()
  librosa.display.specshow(S_db, y_axis='log', x_axis='time', ax=ax[1])
  ax[1].set(title='log Power spectrogram')
  ax[1].fill_between(times, np.maximum(0, centroid[0] - spec_bw[0]), np.minimum(centroid[0] + spec_bw[0], rate/2), alpha=0.5, label='Centroid +- bandwidth')
  ax[1].plot(times, centroid[0], label='Spectral centroid', color='w')
  ax[1].legend(loc='lower right')

def displayRolloff(signal, rate):
  librosa.feature.spectral_rolloff(y=signal, sr=rate)
  rolloff = librosa.feature.spectral_rolloff(y=signal, sr=rate, roll_percent=0.99)
  rolloff_min = librosa.feature.spectral_rolloff(y=signal, sr=rate, roll_percent=0.01)
  S, phase = librosa.magphase(librosa.stft(signal))
  S_db = librosa.amplitude_to_db(S, ref=np.max)
  librosa.feature.spectral_rolloff(S=S, sr=rate)
  librosa.feature.spectral_rolloff(y=signal, sr=rate, roll_percent=0.95)
  fig, ax = plt.subplots()
  librosa.display.specshow(S_db, y_axis='log', x_axis='time', ax=ax)
  ax.plot(librosa.times_like(rolloff), rolloff[0], label='Roll-off frequency (0.99)')
  ax.plot(librosa.times_like(rolloff), rolloff_min[0], color='w', label='Roll-off frequency (0.01)')
  ax.legend(loc='lower right')
  ax.set(title='log Power spectrogram')

def displayChromastft(signal, rate, fftlen):
  S = np.abs(librosa.stft(signal))
  chroma = librosa.feature.chroma_stft(S=S, sr=rate)
  S = np.abs(librosa.stft(signal, n_fft=fftlen))**2
  S_db = librosa.amplitude_to_db(S, ref=np.max)
  chroma = librosa.feature.chroma_stft(S=S, sr=rate)
  fig, ax = plt.subplots(nrows=2, sharex=True)
  img = librosa.display.specshow(S_db, x_axis='time', y_axis='log', ax=ax[0])
  fig.colorbar(img, ax=[ax[0]])
  ax[0].label_outer()
  img = librosa.display.specshow(chroma, x_axis='time', y_axis='chroma', ax=ax[1])
  fig.colorbar(img, ax=[ax[1]])

def displayChromacqt(signal, rate, n_chroma, n_fft):
  chroma_stft = librosa.feature.chroma_stft(y=signal, sr=rate, n_chroma=n_chroma, n_fft=n_fft)
  chroma_cq = librosa.feature.chroma_cqt(y=signal, sr=rate)
  fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
  img1 = librosa.display.specshow(chroma_stft, x_axis='time', y_axis='chroma', ax=ax[0])
  ax[0].set(title='chroma_stft')
  ax[0].label_outer()
  img2 = librosa.display.specshow(chroma_cq, x_axis='time', y_axis='chroma', ax=ax[1])
  ax[1].set(title='chroma_cqt')
  fig.colorbar(img2, ax=ax)

def displayChromacens(signal, rate):
  chroma_cens = librosa.feature.chroma_cens(y=signal, sr=rate)
  chroma_cq = librosa.feature.chroma_cqt(y=signal, sr=rate)
  fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
  img1 = librosa.display.specshow(chroma_cq, x_axis='time', y_axis='chroma', ax=ax[0])
  ax[0].set(title='chroma_cq')
  ax[0].label_outer()
  img2 = librosa.display.specshow(chroma_cens, x_axis='time', y_axis='chroma', ax=ax[1])
  ax[1].set(title='chroma_cens')
  fig.colorbar(img1, ax=ax)

def displayChromavqt(signal, rate, n_bins):
  chroma_cq = librosa.feature.chroma_cqt(y=signal, sr=rate, n_chroma=n_bins)
  chroma_vq = librosa.feature.chroma_vqt(y=signal, sr=rate, intervals='ji5', bins_per_octave=n_bins)
  fig, ax = plt.subplots(nrows=2, sharex=True)
  img1 = librosa.display.specshow(chroma_cq, x_axis='time', y_axis='chroma', ax=ax[0], bins_per_octave=n_bins)
  ax[0].set(ylabel='chroma_cqt')
  ax[0].label_outer()
  img2 = librosa.display.specshow(chroma_vq, y_axis='chroma_fjs', x_axis='time', ax=ax[1], bins_per_octave=n_bins, intervals='ji5')
  ax[1].set(ylabel='chroma_vqt')
  fig.colorbar(img2, ax=ax)

def plot_wave(signal, rate):  
  displayWaveform(signal, rate)
  displaySpectrum(signal, rate)
  displaySpectrogram(signal, rate, fftlen=512)
  displayMelspectrogram(signal, rate)
  diaplayMFCC(signal, rate)
#   displayZCR(signal, rate)
#   displayCentroids(signal, rate)
#   displayBandwidth(signal, rate)
#   displayRolloff(signal, rate)
#   displayChromastft(signal, rate, fftlen=512)
#   displayChromacqt(signal, rate, n_chroma=12, n_fft=512)
#   displayChromacens(signal, rate)
#   displayChromavqt(signal, rate, n_bins=24)

SIGNAL = G32h[0:RATE]
plot_wave(SIGNAL, RATE)
IPython.display.Audio(data=SIGNAL, rate=RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Cut signal data

# %%
G32h = G32h[0:1056*RATE]
G41h = G41h[120*RATE:840*RATE]
G42h = G42h[0:1260*RATE]
G43b = G43b[100*RATE:2240*RATE]

S11 = S11[0:150*RATE]
S12 = S12[210*RATE:416*RATE]
S13 = S13[140*RATE:374*RATE]
S14 = S14[2*RATE:136*RATE]
S21 = S21[0:103*RATE]
S22 = S22[0:156*RATE]
S23 = S23[42*RATE:126*RATE]
S31 = S31[0:86*RATE]
S32 = S32[76*RATE:213*RATE]
S33 = S33[33*RATE:130*RATE]
S41 = S41[0:41*RATE]
S42 = S42[100*RATE:123*RATE]
S43 = S43[115*RATE:135*RATE]
S51 = S51[3*RATE:28*RATE]
S52 = S52[103*RATE:126*RATE]
S53 = S53[126*RATE:153*RATE]
S54 = S54[157*RATE:181*RATE]
S61 = S61[40*RATE:57*RATE]
S62 = S62[128*RATE:150*RATE]
S63 = S63[35*RATE:51*RATE]
S71 = S71[16*RATE:88*RATE]
S72 = S72[86*RATE:328*RATE]
S73 = S73[116*RATE:260*RATE]
S74 = S74[112*RATE:286*RATE]
S81 = S81[0:78*RATE]
S82 = S82[84*RATE:189*RATE]
S83 = S83[130*RATE:312*RATE]
S91 = S91[0:45*RATE]
S92 = S92[50*RATE:108*RATE]
S93 = S93[72*RATE:228*RATE]
S94 = S94[68*RATE:258*RATE]

B11 = B11[4*RATE:484*RATE]
B12 = B12[4*RATE:382*RATE]
B13 = B13[0*RATE:280*RATE]
B21 = B21[4*RATE:157*RATE]
B22 = B22[4*RATE:170*RATE]
B23 = B23[8*RATE:166*RATE]
B31 = B31[15*RATE:146*RATE]
B32 = B32[12*RATE:258*RATE]
B33 = B33[12*RATE:177*RATE]
B41 = B41[10*RATE:109*RATE]
B42 = B42[6*RATE:64*RATE]
B43 = B43[6*RATE:88*RATE]
B51 = B51[8*RATE:78*RATE]
B52 = B52[4*RATE:268*RATE]
B53 = B53[8*RATE:97*RATE]
B54 = B54[4*RATE:123*RATE]
B61 = B61[4*RATE:205*RATE]
B62 = B62[4*RATE:135*RATE]
B63 = B63[6*RATE:124*RATE]
B71 = B71[4*RATE:296*RATE]
B72 = B72[4*RATE:204*RATE]
B73 = B73[10*RATE:303*RATE]
B81 = B81[6*RATE:182*RATE]
B82 = B82[6*RATE:183*RATE]
B83 = B83[10*RATE:219*RATE]
B91 = B91[4*RATE:201*RATE]
B92 = B92[6*RATE:138*RATE]
B93 = B93[0*RATE:158*RATE]
 
signals_list = ["G32h", "G41h", "G42h", "G43b",
              "S11", "S12", "S13", "S14", "S21", "S22", "S23", "S31", "S32", "S33",
              "S41", "S42", "S43", "S51", "S52", "S53", "S54", "S61", "S62", "S63",
              "S71", "S72", "S73", "S74", "S81", "S82", "S83", "S91", "S92", "S93", "S94",
              "B11", "B12", "B13", "B21", "B22", "B23", "B31", "B32", "B33",
              "B41", "B42", "B43", "B51", "B52", "B53", "B54", "B61", "B62", "B63", 
              "B71", "B72", "B73", "B81", "B82", "B83", "B91", "B92", "B93"]

def check_all():
    for signals in signals_list:
        print(signals, eval(signals).shape)
check_all()
# Out:
# G32h (8650752,)
# G41h (5898240,)
# G42h (10321920,)
# G43b (17530880,)
# S11 (1228800,)
# S12 (1687552,)
# S13 (1916928,)
# S14 (1097728,)
# S21 (843776,)
# S22 (1277952,)
# S23 (688128,)
# S31 (704512,)
# S32 (1122304,)
# S33 (794624,)
# S41 (335872,)
# S42 (188416,)
# S43 (163840,)
# S51 (204800,)
# S52 (188416,)
# S53 (221184,)
# S54 (196608,)
# S61 (139264,)
# S62 (180224,)
# S63 (131072,)
# S71 (589824,)
# S72 (1982464,)
# S73 (1179648,)
# S74 (1425408,)
# S81 (638976,)
# S82 (860160,)
# S83 (1490944,)
# S91 (368640,)
# S92 (475136,)
# S93 (1277952,)
# S94 (1556480,)
# B11 (3932160,)
# B12 (3096576,)
# B13 (2293760,)
# B21 (1253376,)
# B22 (1359872,)
# B23 (1294336,)
# B31 (1073152,)
# B32 (2015232,)
# B33 (1351680,)
# B41 (811008,)
# B42 (475136,)
# B43 (671744,)
# B51 (573440,)
# B52 (2162688,)
# B53 (729088,)
# B54 (974848,)
# B61 (1646592,)
# B62 (1073152,)
# B63 (966656,)
# B71 (2392064,)
# B72 (1638400,)
# B73 (2400256,)
# B81 (1441792,)
# B82 (1449984,)
# B83 (1712128,)
# B91 (1613824,)
# B92 (1081344,)
# B93 (1294336,)

# %% [markdown]
# ## Pick signal data

# %%
def pick_signal(signals):
  sample_size = int(RATE)        # int(RATE/2)
  sample_step = int(sample_size/2) # int(RATE/4)
  sample_data = []
  for i in tqdm(range((len(signals)-sample_size) // sample_step)):
    sample_data.append(signals[i*sample_step : (i*sample_step+sample_size)])
  sample_data = np.stack(sample_data)
  sample_data = np.squeeze(sample_data)
  return sample_data

G32h = pick_signal(G32h)
G41h = pick_signal(G41h)
G42h = pick_signal(G42h)
G43b = pick_signal(G43b)

S11 = pick_signal(S11)
S12 = pick_signal(S12)
S13 = pick_signal(S13)
S14 = pick_signal(S14)
S21 = pick_signal(S21)
S22 = pick_signal(S22)
S23 = pick_signal(S23)
S31 = pick_signal(S31)
S32 = pick_signal(S32)
S33 = pick_signal(S33)
S41 = pick_signal(S41)
S42 = pick_signal(S42)
S43 = pick_signal(S43)
S51 = pick_signal(S51)
S52 = pick_signal(S52)
S53 = pick_signal(S53)
S54 = pick_signal(S54)
S61 = pick_signal(S61)
S62 = pick_signal(S62)
S63 = pick_signal(S63)
S71 = pick_signal(S71)
S72 = pick_signal(S72)
S73 = pick_signal(S73)
S74 = pick_signal(S74)
S81 = pick_signal(S81)
S82 = pick_signal(S82)
S83 = pick_signal(S83)
S91 = pick_signal(S91)
S92 = pick_signal(S92)
S93 = pick_signal(S93)
S94 = pick_signal(S94)

B11 = pick_signal(B11)
B12 = pick_signal(B12)
B13 = pick_signal(B13)
B21 = pick_signal(B21)
B22 = pick_signal(B22)
B23 = pick_signal(B23)
B31 = pick_signal(B31)
B32 = pick_signal(B32)
B33 = pick_signal(B33)
B41 = pick_signal(B41)
B42 = pick_signal(B42)
B43 = pick_signal(B43)
B51 = pick_signal(B51)
B52 = pick_signal(B52)
B53 = pick_signal(B53)
B54 = pick_signal(B54)
B61 = pick_signal(B61)
B62 = pick_signal(B62)
B63 = pick_signal(B63)
B71 = pick_signal(B71)
B72 = pick_signal(B72)
B73 = pick_signal(B73)
B81 = pick_signal(B81)
B82 = pick_signal(B82)
B83 = pick_signal(B83)
B91 = pick_signal(B91)
B92 = pick_signal(B92)
B93 = pick_signal(B93)

check_all()
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 2110/2110 [00:00<00:00, 1897508.89it/s]
# 100%|█████████████████████████████████████████████████████████████████| 1438/1438 [00:00<00:00, 1419155.09it/s]
# 100%|█████████████████████████████████████████████████████████████████| 2518/2518 [00:00<00:00, 1918136.12it/s]
# 100%|█████████████████████████████████████████████████████████████████| 4278/4278 [00:00<00:00, 1984651.31it/s]
# 100%|███████████████████████████████████████████████████████████████████| 298/298 [00:00<00:00, 1491530.54it/s]
# 100%|███████████████████████████████████████████████████████████████████| 410/410 [00:00<00:00, 1628470.30it/s]
# 100%|███████████████████████████████████████████████████████████████████| 466/466 [00:00<00:00, 1676282.73it/s]
# 100%|███████████████████████████████████████████████████████████████████| 266/266 [00:00<00:00, 1475773.63it/s]
# 100%|███████████████████████████████████████████████████████████████████| 204/204 [00:00<00:00, 1421325.61it/s]
# 100%|███████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 1623263.72it/s]
# 100%|███████████████████████████████████████████████████████████████████| 166/166 [00:00<00:00, 1384203.71it/s]
# 100%|███████████████████████████████████████████████████████████████████| 170/170 [00:00<00:00, 1411943.92it/s]
# 100%|███████████████████████████████████████████████████████████████████| 272/272 [00:00<00:00, 1641511.78it/s]
# 100%|███████████████████████████████████████████████████████████████████| 192/192 [00:00<00:00, 1480342.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 862581.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 732338.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 681126.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 63449.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 741162.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 701298.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 768677.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 604584.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 719023.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 577197.80it/s]
# 100%|███████████████████████████████████████████████████████████████████| 142/142 [00:00<00:00, 1329444.57it/s]
# 100%|███████████████████████████████████████████████████████████████████| 482/482 [00:00<00:00, 1814770.67it/s]
# 100%|███████████████████████████████████████████████████████████████████| 286/286 [00:00<00:00, 1601563.34it/s]
# 100%|███████████████████████████████████████████████████████████████████| 346/346 [00:00<00:00, 1721505.56it/s]
# 100%|███████████████████████████████████████████████████████████████████| 154/154 [00:00<00:00, 1383132.37it/s]
# 100%|███████████████████████████████████████████████████████████████████| 208/208 [00:00<00:00, 1509368.91it/s]
# 100%|███████████████████████████████████████████████████████████████████| 362/362 [00:00<00:00, 1749237.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 1108404.66it/s]
# 100%|███████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 1248435.13it/s]
# 100%|███████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 1652140.08it/s]
# 100%|███████████████████████████████████████████████████████████████████| 378/378 [00:00<00:00, 1740336.90it/s]
# 100%|███████████████████████████████████████████████████████████████████| 958/958 [00:00<00:00, 1966785.72it/s]
# 100%|███████████████████████████████████████████████████████████████████| 754/754 [00:00<00:00, 1921327.59it/s]
# 100%|███████████████████████████████████████████████████████████████████| 558/558 [00:00<00:00, 1821339.79it/s]
# 100%|███████████████████████████████████████████████████████████████████| 304/304 [00:00<00:00, 1684370.43it/s]
# 100%|███████████████████████████████████████████████████████████████████| 330/330 [00:00<00:00, 1704581.67it/s]
# 100%|███████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 1671334.34it/s]
# 100%|███████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 1589677.90it/s]
# 100%|███████████████████████████████████████████████████████████████████| 490/490 [00:00<00:00, 1805983.27it/s]
# 100%|███████████████████████████████████████████████████████████████████| 328/328 [00:00<00:00, 1667553.59it/s]
# 100%|███████████████████████████████████████████████████████████████████| 196/196 [00:00<00:00, 1304894.58it/s]
# 100%|███████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 1114570.29it/s]
# 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:00<00:00, 1424480.60it/s]
# 100%|███████████████████████████████████████████████████████████████████| 138/138 [00:00<00:00, 1121732.47it/s]
# 100%|███████████████████████████████████████████████████████████████████| 526/526 [00:00<00:00, 1787847.57it/s]
# 100%|███████████████████████████████████████████████████████████████████| 176/176 [00:00<00:00, 1488301.42it/s]
# 100%|███████████████████████████████████████████████████████████████████| 236/236 [00:00<00:00, 1586307.28it/s]
# 100%|███████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 1779132.13it/s]
# 100%|███████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 1564589.73it/s]
# 100%|███████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 1585568.88it/s]
# 100%|███████████████████████████████████████████████████████████████████| 582/582 [00:00<00:00, 1823065.67it/s]
# 100%|███████████████████████████████████████████████████████████████████| 398/398 [00:00<00:00, 1764622.61it/s]
# 100%|███████████████████████████████████████████████████████████████████| 584/584 [00:00<00:00, 1869827.13it/s]
# 100%|███████████████████████████████████████████████████████████████████| 350/350 [00:00<00:00, 1645747.09it/s]
# 100%|███████████████████████████████████████████████████████████████████| 352/352 [00:00<00:00, 1714744.49it/s]
# 100%|███████████████████████████████████████████████████████████████████| 416/416 [00:00<00:00, 1751837.82it/s]
# 100%|███████████████████████████████████████████████████████████████████| 392/392 [00:00<00:00, 1764127.86it/s]
# 100%|███████████████████████████████████████████████████████████████████| 262/262 [00:00<00:00, 1588016.83it/s]
# 100%|███████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 1679861.55it/s]
# G32h (2110, 8192)
# G41h (1438, 8192)
# G42h (2518, 8192)
# G43b (4278, 8192)
# S11 (298, 8192)
# S12 (410, 8192)
# S13 (466, 8192)
# S14 (266, 8192)
# S21 (204, 8192)
# S22 (310, 8192)
# S23 (166, 8192)
# S31 (170, 8192)
# S32 (272, 8192)
# S33 (192, 8192)
# S41 (80, 8192)
# S42 (44, 8192)
# S43 (38, 8192)
# S51 (48, 8192)
# S52 (44, 8192)
# S53 (52, 8192)
# S54 (46, 8192)
# S61 (32, 8192)
# S62 (42, 8192)
# S63 (30, 8192)
# S71 (142, 8192)
# S72 (482, 8192)
# S73 (286, 8192)
# S74 (346, 8192)
# S81 (154, 8192)
# S82 (208, 8192)
# S83 (362, 8192)
# S91 (88, 8192)
# S92 (114, 8192)
# S93 (310, 8192)
# S94 (378, 8192)
# B11 (958, 8192)
# B12 (754, 8192)
# B13 (558, 8192)
# B21 (304, 8192)
# B22 (330, 8192)
# B23 (314, 8192)
# B31 (260, 8192)
# B32 (490, 8192)
# B33 (328, 8192)
# B41 (196, 8192)
# B42 (114, 8192)
# B43 (162, 8192)
# B51 (138, 8192)
# B52 (526, 8192)
# B53 (176, 8192)
# B54 (236, 8192)
# B61 (400, 8192)
# B62 (260, 8192)
# B63 (234, 8192)
# B71 (582, 8192)
# B72 (398, 8192)
# B73 (584, 8192)
# B81 (350, 8192)
# B82 (352, 8192)
# B83 (416, 8192)
# B91 (392, 8192)
# B92 (262, 8192)
# B93 (314, 8192)

# %% [markdown]
# ## Convert signal data

# %%
# 1D original
def wave2wave(X, show):
    if show==1:
        print("waveform: ", X.shape)
    return X

# 1D spectrum
def wave2spectrum(X, show):
    spectrum = np.abs(np.fft.fft(X))
    spectrum = spectrum[0:len(spectrum)//2]
    if show==1:
        print("spectrum: ", spectrum.shape)
    return spectrum

# 2D spectrogram
def wave2spectrogram(X, show):
    spectrogram = np.abs(librosa.stft(X))
    spectrogram_db = librosa.amplitude_to_db(spectrogram, ref=np.max)
    if show==1:
        print("spectrogram_db: ", spectrogram_db.shape)
    return spectrogram_db

# 2D mfcc
def wave2mfcc(X, show):
    mfccs = librosa.feature.mfcc(y=X, sr=RATE)
    if show==1:
         print("mfccs: ", mfccs.shape)
    return mfccs

# 2D ptp
def wave2ptp(X, show):
    autocorr = np.correlate(X, X, mode='full')
    time_delay = np.argmax(autocorr[len(autocorr)//2:]) + 1
    embedding = np.array([X[:-2*time_delay], X[time_delay:-time_delay]]).T
    if show==1:
        plt.scatter(embedding[:, 0], embedding[:, 1])
        plt.title('Phase Trajectory Plot')
        plt.show()
    return embedding

# 2D urp
def wave2urp(X, show):
    urp = RecurrencePlot(threshold=None)
    X_urp = urp.fit_transform(X.reshape(1, -1))[0]
    if show==1:
        plt.imshow(X_urp, cmap='rainbow', origin='lower')
        plt.title('Unthresholded Recurrence Plot')
        plt.colorbar(label='Intensity', fraction=0.0457, pad=0.04)
        plt.tight_layout()
        plt.show()
    return X_urp

# 2D rp
def wave2rp(X, show):
    rp = RecurrencePlot(threshold='point', percentage=20)
    X_rp = rp.fit_transform(X.reshape(1, -1))[0]
    if show==1:
        plt.imshow(X_rp, cmap='binary', origin='lower')
        plt.title('Recurrence Plot')
        plt.colorbar(label='Intensity', fraction=0.0457, pad=0.04)
        plt.tight_layout()
        plt.show()
    return X_rp

#2D mtf
def wave2mtf(X, show):
    mtf = MarkovTransitionField(image_size=227)
    X_mtf = mtf.fit_transform(X.reshape(1, -1))[0]
    if show==1:
        plt.imshow(X_mtf, cmap='rainbow', origin='lower')
        plt.title('Markov Transition Field')
        plt.colorbar(label='Intensity', fraction=0.0457, pad=0.04)
        plt.tight_layout()
        plt.show()
    return X_mtf

# 2D ga(s)f
def wave2gasf(X, show):
    gasf = GramianAngularField(image_size=227, method='summation')
    X_gasf = gasf.fit_transform(X.reshape(1, -1))[0]
    if show==1:
        plt.imshow(X_gasf, cmap='rainbow', origin='lower')
        plt.title('Gramian Angular Summation Fields')
        plt.colorbar(label='Intensity', fraction=0.0457, pad=0.04)
        plt.tight_layout()
        plt.show()
    return X_gasf

# 2D ga(d)f
def wave2gadf(X, show):
    gadf = GramianAngularField(image_size=227, method='difference')
    X_gadf = gadf.fit_transform(X.reshape(1, -1))[0]
    if show==1:
        plt.imshow(X_gadf, cmap='rainbow', origin='lower')
        plt.title('Gramian Angular Difference Fields')
        plt.colorbar(label='Intensity', fraction=0.0457, pad=0.04)
        plt.tight_layout()
        plt.show()
    return X_gadf

# SIGNAL = G32h[0]
print("signal shape: ", SIGNAL.shape)
wave2wave(SIGNAL, 1)
wave2spectrum(SIGNAL, 1)
wave2spectrogram(SIGNAL, 1)
wave2mfcc(SIGNAL, 1)
wave2ptp(SIGNAL, 1)
wave2urp(SIGNAL, 1)
wave2rp(SIGNAL, 1)
wave2mtf(SIGNAL, 1)
wave2gasf(SIGNAL, 1)
wave2gadf(SIGNAL, 1)
SIGNAL = SIGNAL[0:227]
print("signal shape: ", SIGNAL.shape)
wave2wave(SIGNAL, 1)
wave2spectrum(SIGNAL, 1)
wave2spectrogram(SIGNAL, 1)
wave2mfcc(SIGNAL, 1)
wave2ptp(SIGNAL, 1)
wave2urp(SIGNAL, 1)
wave2rp(SIGNAL, 1)
wave2mtf(SIGNAL, 1)
wave2gasf(SIGNAL, 1)
wave2gadf(SIGNAL, 1)
# Out:
# signal shape:  (8192,)
# waveform:  (8192,)
# spectrum:  (4096,)
# spectrogram_db:  (1025, 17)
# mfccs:  (20, 17)
# signal shape:  (227,)
# waveform:  (227,)
# spectrum:  (113,)
# spectrogram_db:  (1025, 1)
# mfccs:  (20, 1)
# /home/svu/e1097232/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=227
#   warnings.warn(
# array([[ 0.        , -0.15625   ,  0.        , ...,  0.16023708,
#         -0.3982178 , -0.84413782],
#        [ 0.15625   ,  0.        ,  0.15625   , ...,  0.3125    ,
#         -0.25      , -0.75      ],
#        [ 0.        , -0.15625   ,  0.        , ...,  0.16023708,
#         -0.3982178 , -0.84413782],
#        ...,
#        [-0.16023708, -0.3125    , -0.16023708, ...,  0.        ,
#         -0.54005626, -0.91913764],
#        [ 0.3982178 ,  0.25      ,  0.3982178 , ...,  0.54005626,
#          0.        , -0.56082492],
#        [ 0.84413782,  0.75      ,  0.84413782, ...,  0.91913764,
#          0.56082492,  0.        ]])

# %%
def wave2others(signals):
    function = wave2spectrum
    results = []
    if function == wave2rp or function == wave2urp:
        random.seed(42)
        shorter_length = 227
        for signal in tqdm(signals):
            shorter_arrays = [signal[i:i+shorter_length] for i in range(len(signal) - shorter_length + 1)]
            signal = random.choice(shorter_arrays)
            result = wave2spectrum(signal, 0)
            result = function(signal, 0)
            results.append(result)
    else:
        for signal in tqdm(signals):
            result = wave2spectrum(signal, 0)
            result = function(signal, 0)
            results.append(result)
    results = np.array(results)
    return results

G32h = wave2others(G32h)
G41h = wave2others(G41h)
G42h = wave2others(G42h)
G43b = wave2others(G43b)

S11 = wave2others(S11)
S12 = wave2others(S12)
S13 = wave2others(S13)
S14 = wave2others(S14)
S21 = wave2others(S21)
S22 = wave2others(S22)
S23 = wave2others(S23)
S31 = wave2others(S31)
S32 = wave2others(S32)
S33 = wave2others(S33)
S41 = wave2others(S41)
S42 = wave2others(S42)
S43 = wave2others(S43)
S51 = wave2others(S51)
S52 = wave2others(S52)
S53 = wave2others(S53)
S54 = wave2others(S54)
S61 = wave2others(S61)
S62 = wave2others(S62)
S63 = wave2others(S63)
S71 = wave2others(S71)
S72 = wave2others(S72)
S73 = wave2others(S73)
S74 = wave2others(S74)
S81 = wave2others(S81)
S82 = wave2others(S82)
S83 = wave2others(S83)
S91 = wave2others(S91)
S92 = wave2others(S92)
S93 = wave2others(S93)
S94 = wave2others(S94)

B11 = wave2others(B11)
B12 = wave2others(B12)
B13 = wave2others(B13)
B21 = wave2others(B21)
B22 = wave2others(B22)
B23 = wave2others(B23)
B31 = wave2others(B31)
B32 = wave2others(B32)
B33 = wave2others(B33)
B41 = wave2others(B41)
B42 = wave2others(B42)
B43 = wave2others(B43)
B51 = wave2others(B51)
B52 = wave2others(B52)
B53 = wave2others(B53)
B54 = wave2others(B54)
B61 = wave2others(B61)
B62 = wave2others(B62)
B63 = wave2others(B63)
B71 = wave2others(B71)
B72 = wave2others(B72)
B73 = wave2others(B73)
B81 = wave2others(B81)
B82 = wave2others(B82)
B83 = wave2others(B83)
B91 = wave2others(B91)
B92 = wave2others(B92)
B93 = wave2others(B93)

check_all()
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 2110/2110 [00:00<00:00, 3746.74it/s]
# 100%|████████████████████████████████████████████████████████████████████| 1438/1438 [00:00<00:00, 3867.36it/s]
# 100%|████████████████████████████████████████████████████████████████████| 2518/2518 [00:00<00:00, 3925.88it/s]
# 100%|████████████████████████████████████████████████████████████████████| 4278/4278 [00:01<00:00, 3748.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 298/298 [00:00<00:00, 4014.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 410/410 [00:00<00:00, 4067.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 466/466 [00:00<00:00, 4068.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 266/266 [00:00<00:00, 4022.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 204/204 [00:00<00:00, 4005.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 3990.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 166/166 [00:00<00:00, 4003.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 170/170 [00:00<00:00, 3980.04it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 272/272 [00:00<00:00, 4019.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 192/192 [00:00<00:00, 3895.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 3952.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 4036.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 3780.89it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 4000.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 3845.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 3888.53it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 3962.74it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 4027.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 4040.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 4028.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 142/142 [00:00<00:00, 4109.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 482/482 [00:00<00:00, 4087.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 286/286 [00:00<00:00, 4041.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 346/346 [00:00<00:00, 4080.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 154/154 [00:00<00:00, 4100.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 208/208 [00:00<00:00, 4052.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 362/362 [00:00<00:00, 4074.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 4043.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 3983.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 4056.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 378/378 [00:00<00:00, 3998.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 958/958 [00:00<00:00, 4174.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 754/754 [00:00<00:00, 4166.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 558/558 [00:00<00:00, 4137.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 304/304 [00:00<00:00, 4104.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 330/330 [00:00<00:00, 3984.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 4121.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 4185.55it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 490/490 [00:00<00:00, 4167.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 328/328 [00:00<00:00, 4227.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 196/196 [00:00<00:00, 4185.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 4147.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 162/162 [00:00<00:00, 4108.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138/138 [00:00<00:00, 4211.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 526/526 [00:00<00:00, 4173.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 176/176 [00:00<00:00, 4197.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 236/236 [00:00<00:00, 4228.60it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 4187.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 4215.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 4214.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 582/582 [00:00<00:00, 4190.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 398/398 [00:00<00:00, 4174.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 584/584 [00:00<00:00, 4110.97it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 350/350 [00:00<00:00, 4110.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 352/352 [00:00<00:00, 4070.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 416/416 [00:00<00:00, 4222.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 392/392 [00:00<00:00, 4213.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 262/262 [00:00<00:00, 4137.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 4200.78it/s]
# G32h (2110, 4096)
# G41h (1438, 4096)
# G42h (2518, 4096)
# G43b (4278, 4096)
# S11 (298, 4096)
# S12 (410, 4096)
# S13 (466, 4096)
# S14 (266, 4096)
# S21 (204, 4096)
# S22 (310, 4096)
# S23 (166, 4096)
# S31 (170, 4096)
# S32 (272, 4096)
# S33 (192, 4096)
# S41 (80, 4096)
# S42 (44, 4096)
# S43 (38, 4096)
# S51 (48, 4096)
# S52 (44, 4096)
# S53 (52, 4096)
# S54 (46, 4096)
# S61 (32, 4096)
# S62 (42, 4096)
# S63 (30, 4096)
# S71 (142, 4096)
# S72 (482, 4096)
# S73 (286, 4096)
# S74 (346, 4096)
# S81 (154, 4096)
# S82 (208, 4096)
# S83 (362, 4096)
# S91 (88, 4096)
# S92 (114, 4096)
# S93 (310, 4096)
# S94 (378, 4096)
# B11 (958, 4096)
# B12 (754, 4096)
# B13 (558, 4096)
# B21 (304, 4096)
# B22 (330, 4096)
# B23 (314, 4096)
# B31 (260, 4096)
# B32 (490, 4096)
# B33 (328, 4096)
# B41 (196, 4096)
# B42 (114, 4096)
# B43 (162, 4096)
# B51 (138, 4096)
# B52 (526, 4096)
# B53 (176, 4096)
# B54 (236, 4096)
# B61 (400, 4096)
# B62 (260, 4096)
# B63 (234, 4096)
# B71 (582, 4096)
# B72 (398, 4096)
# B73 (584, 4096)
# B81 (350, 4096)
# B82 (352, 4096)
# B83 (416, 4096)
# B91 (392, 4096)
# B92 (262, 4096)
# B93 (314, 4096)

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Build dataset

# %%
# Rock type(3-classes: 0_granite, 1_sandstone, 2_bas
X_0 = np.concatenate((G32h, G41h, G42h, G43b), axis=0)
X_1 = np.concatenate((S11, S12, S13, S14, S21, S22, S23, S31, S32, S33,
                      S41, S42, S43, S51, S52, S53, S54, S61, S62, S63,
                      S71, S72, S73, S74, S81, S82, S83, S91, S92, S93, S94), axis=0)
X_2 = np.concatenate((B11, B12, B13, B21, B22, B23, B31, B32, B33,
                      B41, B42, B43, B51, B52, B53, B54, B61, B62, B63,
                      B71, B72, B73, B81, B82, B83, B91, B92, B93), axis=0)
min_size = min(len(X_0), len(X_1), len(X_2))
X_0 = X_0[np.random.choice(len(X_0), size=min_size, replace=False)]
X_1 = X_1[np.random.choice(len(X_1), size=min_size, replace=False)]
X_2 = X_2[np.random.choice(len(X_2), size=min_size, replace=False)]
Y_0 = np.repeat(0, len(X_0))
Y_1 = np.repeat(1, len(X_1))
Y_2 = np.repeat(2, len(X_2))
X_set = np.concatenate((X_0, X_1, X_2), axis=0)
Y_set = np.concatenate((Y_0, Y_1, Y_2), axis=0)
num_classes = len(np.unique(Y_set))

# # Bit type(3-classes: 0_IDB, 1_PDC, 2_MMC)
# X_0 = np.concatenate((G32h, G41h, G42h, G43b,
#                       S11, S12, S13, S14, S21, S22, S23, S31, S32, S33,
#                       B11, B12, B13, B21, B22, B23, B31, B32, B33), axis=0)
# X_1 = np.concatenate((S41, S42, S43, S51, S52, S53, S54, S61, S62, S63,
#                       B41, B42, B43, B51, B52, B53, B54, B61, B62, B63), axis=0)
# X_2 = np.concatenate((S71, S72, S73, S74, S81, S82, S83, S91, S92, S93, S94,
#                       B71, B72, B73, B81, B82, B83, B91, B92, B93), axis=0)
# min_size = min(len(X_0), len(X_1), len(X_2))
# X_0 = X_0[np.random.choice(len(X_0), size=min_size, replace=False)]
# X_1 = X_1[np.random.choice(len(X_1), size=min_size, replace=False)]
# X_2 = X_2[np.random.choice(len(X_2), size=min_size, replace=False)]
# Y_0 = np.repeat(0, len(X_0))
# Y_1 = np.repeat(1, len(X_1))
# Y_2 = np.repeat(2, len(X_2))
# X_set = np.concatenate((X_0, X_1, X_2), axis=0)
# Y_set = np.concatenate((Y_0, Y_1, Y_2), axis=0)
# num_classes = len(np.unique(Y_set)) 

print(type(X_0), X_0.shape, type(Y_0), type(Y_0[0]), Y_0.shape)
print(type(X_1), X_1.shape, type(Y_1), type(Y_1[0]), Y_1.shape)
print(type(X_2), X_2.shape, type(Y_2), type(Y_2[0]), Y_2.shape)
print(type(X_set), X_set.shape, type(Y_set), type(Y_set[0]), Y_set.shape)
# Out:
# <class 'numpy.ndarray'> (6080, 4096) <class 'numpy.ndarray'> <class 'numpy.int64'> (6080,)
# <class 'numpy.ndarray'> (6080, 4096) <class 'numpy.ndarray'> <class 'numpy.int64'> (6080,)
# <class 'numpy.ndarray'> (6080, 4096) <class 'numpy.ndarray'> <class 'numpy.int64'> (6080,)
# <class 'numpy.ndarray'> (18240, 4096) <class 'numpy.ndarray'> <class 'numpy.int64'> (18240,)

# %% [markdown]
# ### ML model

# %% [markdown]
# #### Normal model

# %%
# x_train, x_test, y_train, y_test = train_test_split(X_set, Y_set, test_size=0.2, random_state=42)

# print("x_train:", x_train.shape)
# print("y_train:", y_train.shape)  
# print("x_test:", x_test.shape)
# print("y_test:", y_test.shape)

# %%
# # K-Nearest Neighbors (KNN)
# def make_knn():
#     model = KNeighborsClassifier(n_neighbors=num_classes) 
#     model.fit(x_train, y_train)
#     return model

# # Decision Tree Classifier
# def make_dtc():
#     model = DecisionTreeClassifier()
#     model.fit(x_train, y_train)
#     return model

# # Random Forest Classifier
# def make_rfc():
#     model = RandomForestClassifier(n_estimators=100, random_state=42)
#     model.fit(x_train, y_train)
#     return model

# # Naive Bayes Classifier
# def make_nbc():
#     model = GaussianNB()
#     model.fit(x_train, y_train)
#     return model

# time0 = time.time()
# model = make_nbc()
# time1 = time.time()
# y_pred = model.predict(x_test)
# time2 = time.time()
# accuracy = accuracy_score(y_test, y_pred)
# precision = precision_score(y_test, y_pred, average='weighted')
# recall = recall_score(y_test, y_pred, average='weighted')
# f1 = f1_score(y_test, y_pred, average='weighted')
# classification_report = classification_report(y_test, y_pred)
# confusion_matrix = confusion_matrix(y_test, y_pred)
# time3 = time.time()

# print("Train time:", time1-time0)
# print("Predict time:", time2-time1)
# print("Process time:", time3-time2)
# print("Function time:", time3-time1)
# print("Accuracy:", accuracy)
# print("Precision:", precision)
# print("Recall:", recall)
# print("F1 Score:", f1)
# print("\nClassification Report:\n", classification_report)
# print("\nConfusion Matrix:\n", confusion_matrix)

# %%
# # labels = ['granite', 'sandstone', 'basalt']
# # fig, ax = plt.subplots(figsize=(8, 6))
# # sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Oranges', cbar=True, square=True,
# #             xticklabels=labels, yticklabels=labels, ax=ax, cbar_kws={'label': 'Count'})
# # fontsize = 12
# # ax.set_xlabel('Predicted Label', fontsize=fontsize)
# # ax.set_ylabel('True Label', fontsize=fontsize)
# # ax.set_title('Confusion Matrix', fontsize=fontsize)
# # ax.tick_params(axis='x', labelsize=fontsize)
# # ax.tick_params(axis='y', labelsize=fontsize)
# # plt.show()

# # # Define the confusion matrix array
# # confusion_matrix = np.array([[50, 5, 0],
# #                              [3, 45, 2],
# #                              [10, 8, 40]])
# # Create a figure and axes
# fig, ax = plt.subplots()
# # Define the font size for the annotations
# annot_font_family = 'Times New Roman'
# annot_font_weight = 'bold'
# annot_font_size = 18
# # Plot the confusion matrix with custom font size for the annotations
# sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d', xticklabels=False, yticklabels=False,
#             annot_kws={'fontsize': annot_font_size,
#                       #  'fontfamily': annot_font_family,
#                        'fontweight': annot_font_weight}, ax=ax)
# # Remove x-label, y-label, x-tick labels, and y-tick labels
# ax.set_xlabel('')
# ax.set_ylabel('')
# ax.set_xticklabels([])
# ax.set_yticklabels([])
# # Show the plot
# plt.show()
# plt.savefig('cm.png', dpi=300)

# %% [markdown]
# ### DL model

# %%
X_set = np.expand_dims(X_set, axis=-1)
Y_set = to_categorical(Y_set, num_classes=num_classes)

x_train, x_test, y_train, y_test = train_test_split(X_set, Y_set, test_size=0.2, random_state=42)

print("x_train:", x_train.shape)
print("y_train:", y_train.shape)  
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (14592, 4096, 1)
# y_train: (14592, 3)
# x_test: (3648, 4096, 1)
# y_test: (3648, 3)

# %%
def make_1Dgap():
    model = Sequential()
    model.add(Conv1D(64, 3, activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(MaxPooling1D(2))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def make_1Ddense():
    model = Sequential()
    model.add(Conv1D(64, 7, strides=2, activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(MaxPooling1D(3, strides=2, padding='same'))
    model.add(Conv1D(32, 3, activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(Conv1D(32, 3, activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(Conv1D(32, 3, activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(GlobalAveragePooling1D())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def make_1Dalex():
    model = Sequential()
    model.add(Conv1D(96, 11, strides=4, activation='relu', input_shape=x_train.shape[1:]))  # (227, 1)
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Conv1D(256, 5, activation='relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Conv1D(384, 3, activation='relu'))
    model.add(Conv1D(384, 3, activation='relu'))
    model.add(Conv1D(256, 3, activation='relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def make_1Dvgg():
    model = Sequential()
    model.add(Conv1D(64, 3, activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(Conv1D(64, 3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(128, 3, activation='relu', padding='same'))
    model.add(Conv1D(128, 3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(256, 3, activation='relu', padding='same'))
    model.add(Conv1D(256, 3, activation='relu', padding='same'))
    model.add(Conv1D(256, 3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(Conv1D(512, 3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))  
    return model


def make_2Dgap():
    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(MaxPooling2D((2, 2)))
    model.add(GlobalAveragePooling2D())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def make_2Ddense():
    model = Sequential()
    model.add(Conv2D(64, (7, 7), strides=(2, 2), activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(Concatenate())
    model.add(GlobalAveragePooling2D())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def make_2Dalex():
    model = Sequential()
    model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=x_train.shape[1:]))  # (227, 227, 3)
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Conv2D(256, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Conv2D(384, (3, 3), activation='relu'))
    model.add(Conv2D(384, (3, 3), activation='relu'))
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))  
    return model

def make_2Dvgg():
    model = Sequential()
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]))
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

time0 = time.time()
model = make_1Dalex()
time1 = time.time()
model.summary()
# visualkeras.layered_view(model,legend=True)
# keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 1022, 96)          1152
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 510, 96)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 506, 256)          123136
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 252, 256)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 250, 384)          295296
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 248, 384)          442752
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 246, 256)          295168
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 122, 256)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 31232)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              127930368
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 145,881,475
# Trainable params: 145,881,475
# Non-trainable params: 0
# _________________________________________________________________
# 2023-07-03 16:51:18.133074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30999 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:1d:00.0, compute capability: 7.0

# %% [markdown]
# ### Complete & Train

# %%
time2 = time.time()
model.compile(optimizer='adam',                # tf.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)
              loss='categorical_crossentropy', # loss='binary_crossentropy'
              metrics=['accuracy',
                       keras.metrics.AUC(),
                       keras.metrics.Precision(),
                       keras.metrics.Recall()])

callbacks = [
            #  keras.callbacks.ModelCheckpoint("best_model.hdf5",
            #                                  monitor="loss",
            #                                  mode="min",
            #                                  save_best_only=True),
#              keras.callbacks.EarlyStopping(monitor="val_loss",
#                                            mode="min",
#                                            verbose=1,
#                                            patience=10,
#                                            restore_best_weights=True), 
             keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                               factor=0.2,
                                               patience=2,
                                               min_lr=0.000001),
            # keras.callbacks.TensorBoard(log_dir=os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_logs"),
            #                             histogram_freq=1,
            #                             write_graph=True, 
            #                             write_images=True),
            ]

history = model.fit(x_train, y_train,
                    validation_split=0.2, 
                    epochs=200, 
                    batch_size=64, 
                    callbacks=callbacks, 
                    shuffle=True)
time3 = time.time()
# Out:
# 2023-07-03 16:51:18.871912: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2023-07-03 16:51:22.115325: I tensorflow/stream_executor/cuda/cuda_dnn.cc:381] Loaded cuDNN version 8204
# 183/183 [==============================] - 15s 34ms/step - loss: 0.7232 - accuracy: 0.9462 - auc: 0.9863 - precision: 0.9525 - recall: 0.9371 - val_loss: 0.0080 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
# Epoch 2/200
# 183/183 [==============================] - 5s 30ms/step - loss: 0.0455 - accuracy: 0.9908 - auc: 0.9982 - precision: 0.9913 - recall: 0.9906 - val_loss: 0.0011 - val_accuracy: 0.9997 - val_auc: 1.0000 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 3/200
# 183/183 [==============================] - 5s 30ms/step - loss: 0.0041 - accuracy: 0.9990 - auc: 0.9999 - precision: 0.9990 - recall: 0.9990 - val_loss: 0.0018 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9986
# Epoch 4/200
# 183/183 [==============================] - 5s 30ms/step - loss: 0.0401 - accuracy: 0.9938 - auc: 0.9985 - precision: 0.9939 - recall: 0.9938 - val_loss: 8.4918e-04 - val_accuracy: 0.9997 - val_auc: 1.0000 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 5/200
# 183/183 [==============================] - 5s 29ms/step - loss: 0.0113 - accuracy: 0.9975 - auc: 0.9996 - precision: 0.9975 - recall: 0.9975 - val_loss: 2.2781e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 6/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1084e-04 - accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 1.7270e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 7/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1991e-04 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.6400e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.4265e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3438e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2353e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.3485e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 10/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9097e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6921e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 11/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3917e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5887e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 12/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.2316e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4955e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.2228e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4695e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 14/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.2850e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3128e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 15/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.4878e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3054e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 16/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.2807e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2989e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 17/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.1514e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2949e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 18/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.2553e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2946e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 19/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.2762e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2898e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 20/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.1562e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2852e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 21/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.8523e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2635e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 22/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2562e-04 - accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 2.3083e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 23/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.6842e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3106e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 24/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.9516e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.3038e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 25/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.6874e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2922e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 26/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.7705e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2789e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 27/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.6026e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2759e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 28/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.0168e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2779e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.5934e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2659e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1097e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2287e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 31/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.5194e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2189e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9463e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2075e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3063e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1991e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 34/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1571e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1866e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.5503e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1732e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 36/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.0356e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1505e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 37/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2021e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0866e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 38/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.2812e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0510e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 39/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.6128e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9581e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 40/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.8545e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8905e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 41/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.1781e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8728e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 42/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5775e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7789e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 43/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.9222e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7537e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 44/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5050e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7372e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 45/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3109e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7136e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 46/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.6020e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7034e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 47/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9232e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6812e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 48/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5348e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6620e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 49/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.2801e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6508e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 50/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3744e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6245e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 51/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.0417e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5516e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 52/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1647e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5327e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 53/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.1911e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4592e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 54/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.6489e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3288e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 55/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.1243e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3139e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 56/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.9654e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2551e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 57/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2765e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1517e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 58/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.0555e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1630e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 59/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5315e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1471e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 60/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4369e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1263e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 61/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5425e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0959e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 62/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.2692e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0385e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 63/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.1811e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.8610e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 64/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.9802e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.5888e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 65/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.3104e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.3533e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 66/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.7240e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.1676e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 67/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.1686e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.1182e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 68/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2244e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.9969e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 69/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.0029e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.6104e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 70/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.0392e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.3691e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 71/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.2266e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.7262e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 72/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.1465e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.8235e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 73/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.2114e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.6634e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 74/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3361e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.4891e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 75/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.0574e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.9955e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 76/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9660e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.8616e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 77/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3111e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.1053e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 78/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.0062e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.7085e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 79/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3775e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.5517e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 80/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7041e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.4602e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 81/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1553e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.3782e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 82/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4336e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.4186e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 83/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.1605e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.3169e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 84/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.6800e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.1622e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 85/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.0359e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.4129e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 86/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.4551e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.2104e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 87/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1737e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.0969e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 88/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1388e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.0854e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 89/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1169e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.9103e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 90/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1613e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.8674e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 91/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.5300e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.8560e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 92/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3633e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.6657e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 93/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1112e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.5077e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 94/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.0317e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.3321e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 95/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4846e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.4252e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 96/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1202e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.3301e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 97/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.3485e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.2704e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 98/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2774e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.0226e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 99/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.7709e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.9724e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 100/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.4083e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.9046e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 101/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3884e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6412e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 102/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2946e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4015e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 103/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.7478e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2652e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 104/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1245e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2672e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 105/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.9185e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1737e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 106/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.7450e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0320e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 107/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.9454e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9087e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 108/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4829e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0516e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 109/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.0025e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9658e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 110/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.0778e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9238e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 111/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5025e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8707e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 112/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.2395e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7735e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 113/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.4933e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7078e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 114/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.3942e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6433e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 115/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.0634e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5220e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 116/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.0234e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6551e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 117/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.1499e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1434e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 118/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.5788e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0785e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 119/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.7727e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0189e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 120/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.5089e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4999e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 121/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.6220e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4427e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 122/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7361e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2769e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 123/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.4728e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1822e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 124/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.8262e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0667e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 125/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.3790e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0271e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 126/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3290e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.9254e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 127/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.2477e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8911e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 128/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.0886e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7706e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 129/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9729e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.8147e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 130/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1051e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7302e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 131/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.1009e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6334e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 132/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9463e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4705e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 133/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.3753e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4987e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 134/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.5063e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5256e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 135/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.7051e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4530e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 136/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.6896e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4244e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 137/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.7154e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4260e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 138/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.8733e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4068e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 139/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.9208e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3582e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 140/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.7430e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3382e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 141/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7651e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.3002e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 142/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7515e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2729e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 143/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4103e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2157e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 144/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.7318e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2827e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 145/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.9710e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1679e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 146/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.4291e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0626e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 147/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.0445e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2300e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 148/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.6134e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2182e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 149/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7491e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2035e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 150/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.5544e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0724e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 151/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.4757e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0066e-07 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 152/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.3706e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.1598e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 153/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.7884e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.0536e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 154/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4208e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.2042e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 155/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.6003e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.5835e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 156/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.7189e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.6448e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 157/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.4094e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.8607e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 158/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2861e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.1466e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 159/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4799e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.0853e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 160/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.1908e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.6198e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 161/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.3102e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.1252e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 162/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.4327e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.0680e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 163/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9863e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.8393e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 164/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9037e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.0757e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 165/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.1532e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.0348e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 166/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.6779e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.2921e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 167/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9498e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.1451e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 168/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.3020e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.7331e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 169/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.7374e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.5657e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 170/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.3441e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.2273e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 171/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.4547e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.9787e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 172/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.2045e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.3661e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 173/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5445e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.1905e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 174/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.1469e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.1783e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 175/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7336e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.1497e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 176/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.9344e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.8720e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 177/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.7273e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.5290e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 178/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.7320e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.1042e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 179/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.9096e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.7530e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 180/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9867e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.5244e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 181/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.1304e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.3161e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 182/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.1691e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.2344e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 183/200
# 183/183 [==============================] - 5s 29ms/step - loss: 9.2640e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.1323e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 184/200
# 183/183 [==============================] - 5s 29ms/step - loss: 4.6552e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.2630e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 185/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.9860e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.0261e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 186/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.8594e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4095e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 187/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3917e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2951e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 188/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.8365e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1930e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 189/200
# 183/183 [==============================] - 5s 29ms/step - loss: 3.0362e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2135e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 190/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.9733e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.0705e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 191/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.3977e-06 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8301e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 192/200
# 183/183 [==============================] - 5s 29ms/step - loss: 5.7554e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7607e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 193/200
# 183/183 [==============================] - 5s 29ms/step - loss: 2.5328e-05 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5647e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 194/200
# 183/183 [==============================] - 5s 29ms/step - loss: 8.1234e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5361e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 195/200
# 183/183 [==============================] - 5s 29ms/step - loss: 7.0111e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6831e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 196/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.7635e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6668e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 197/200
# 183/183 [==============================] - 5s 29ms/step - loss: 6.6838e-08 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6749e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 198/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.0580e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.6463e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 199/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.4319e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5606e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 200/200
# 183/183 [==============================] - 5s 29ms/step - loss: 1.2243e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.5361e-08 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000

# %% [markdown]
# ### Show model results

# %%
y_test_true = np.argmax(y_test, axis=1)
time4 = time.time()
y_test_pred = np.argmax(model.predict(x_test), axis=1)
time5 = time.time()
accuracy = accuracy_score(y_test_true, y_test_pred)
precision = precision_score(y_test_true, y_test_pred, average='weighted')
recall = recall_score(y_test_true, y_test_pred, average='weighted')
f1 = f1_score(y_test_true, y_test_pred, average='weighted')
classification_report = classification_report(y_test_true, y_test_pred)
confusion_matrix = confusion_matrix(y_test_true, y_test_pred)
time6 = time.time()
print("Train time:", time1-time0+time3-time2)
print("Predict time:", time5-time4)
print("Process time:", time6-time5)
print("Function time:", time6-time4)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nClassification Report:\n", classification_report)
print("\nConfusion Matrix:\n", confusion_matrix)
# Out:
# Train time: 1087.249677181244
# Predict time: 0.6464791297912598
# Process time: 0.01654195785522461
# Function time: 0.6630210876464844
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1181
#            1       1.00      1.00      1.00      1243
#            2       1.00      1.00      1.00      1224
#
#     accuracy                           1.00      3648
#    macro avg       1.00      1.00      1.00      3648
# weighted avg       1.00      1.00      1.00      3648
#
#
# Confusion Matrix:
#  [[1181    0    0]
#  [   0 1243    0]
#  [   0    0 1224]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# # Define the confusion matrix array
# confusion_matrix = np.array([[1181,    0,    0],
#                              [   0, 1243,    0],
#                              [   0,    0, 1224]])
# Create a figure and axes
fig, ax = plt.subplots()
# Define the font size for the annotations
annot_font_family = 'Times New Roman'
annot_font_weight = 'bold'
annot_font_size = 18
# Plot the confusion matrix with custom font size for the annotations
sns.heatmap(confusion_matrix, annot=True, fmt='d', 
            cmap='Oranges', cbar=False, square=True,
            xticklabels=False, yticklabels=False,
            annot_kws={'fontsize': annot_font_size,
                      #  'fontfamily': annot_font_family,
                       'fontweight': annot_font_weight}, ax=ax)
# Remove x-label, y-label, x-tick labels, and y-tick labels
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels([])
ax.set_yticklabels([])
# Show the plot
plt.show()
plt.savefig('cm.png', dpi=300)

# %%
test_loss, test_accuracy, test_auc, test_precision, test_recall = model.evaluate(x_test, y_test)
print("test_loss: ", test_loss)
print("test_accuracy: ", test_accuracy)
print("test_auc: ", test_auc)
print("test_precision: ", test_precision)
print("test_recall: ", test_recall)
# Out:
# 114/114 [==============================] - 1s 6ms/step - loss: 3.2998e-07 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000
# test_loss:  3.299787465493864e-07
# test_accuracy:  1.0
# test_auc:  1.0
# test_precision:  1.0
# test_recall:  1.0

# %% [markdown]
# ### Save model results

# %%
eval_dict = {"y_test_true":y_test_true, "y_test_pred":y_test_pred, "test_loss":test_loss, "test_accuracy":test_accuracy, "test_auc":test_auc, "test_precision":test_precision, "test_recall":test_recall}
model.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_model.hdf5"))
np.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_history.npy"), history.history)
np.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_evaluation.npy"), eval_dict)

# %% [markdown]
# ### Load model results

# %%
# model = load_model(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_model.hdf5"))
# hist = np.load(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_history.npy"), allow_pickle=True).item()
# eval_dict = np.load(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_evaluation.npy"), allow_pickle=True).item()

# %% [markdown]
# ### Plot model results

# %%
def plot_history_metrics(history):
  total_plots = len(history)
  cols = total_plots // 2
  rows = total_plots // cols
  if total_plots % cols != 0:
    rows += 1
  pos = range(1, total_plots + 1)
  plt.figure(figsize=(15, 10))
  for i, (key, value) in enumerate(history.items()):
    plt.subplot(rows, cols, pos[i])
    plt.plot(range(len(value)), value)
    plt.title(str(key))
  plt.savefig(os.path.join(HOST_path, "IDB_drilling_signal/outputs/C_evaluation.png"))
 
plot_history_metrics(history.history)

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Data pre-treatment

# %%
# X_set = np.concatenate((S11,S12,S13,S14,S21,S22,S23,S31,S32,S33,S41,S42,S43,S51,S52,S53,S54,S61,S62,S63,S71,S72,S73,S74,S81,S82,S83,S91,S92,S93,S94), axis=0)
# X_set = X_set.reshape((X_set.shape[0], X_set.shape[1], 1))
# S1Y = [0,0,0, 150, 200, 8]
# S2Y = [0,0,0, 250, 250, 10]
# S3Y = [0,0,0, 350, 150, 6]
# S4Y = [0,1,0, 150, 250, 6]
# S5Y = [0,1,0, 250, 150, 8]
# S6Y = [0,1,0, 350, 200, 10]
# S7Y = [0,0,1, 150, 150, 10]
# S8Y = [0,0,1, 250, 200, 6]
# S9Y = [0,0,1, 350, 250, 8]
# S1L = len(S11)+len(S12)+len(S13)+len(S14)
# S2L = len(S21)+len(S22)+len(S23)
# S3L = len(S31)+len(S32)+len(S33)
# S4L = len(S41)+len(S42)+len(S43)
# S5L = len(S51)+len(S52)+len(S53)+len(S54)
# S6L = len(S61)+len(S62)+len(S63)
# S7L = len(S71)+len(S72)+len(S73)+len(S74)
# S8L = len(S81)+len(S82)+len(S83)
# S9L = len(S91)+len(S92)+len(S93)+len(S94)
# S_1 = [S1Y for _ in range(S1L)]
# S_2 = [S2Y for _ in range(S2L)]
# S_3 = [S3Y for _ in range(S3L)]
# S_4 = [S4Y for _ in range(S4L)]
# S_5 = [S5Y for _ in range(S5L)]
# S_6 = [S6Y for _ in range(S6L)]
# S_7 = [S7Y for _ in range(S7L)]
# S_8 = [S8Y for _ in range(S8L)]
# S_9 = [S9Y for _ in range(S9L)]
# Y_set = np.concatenate((S_1,S_2,S_3,S_4,S_5,S_6,S_7,S_8,S_9), axis=0)
# num_targets = Y_set.shape[1]
# x_train, x_test, y_train, y_test = train_test_split(X_set, Y_set, test_size=0.25, random_state=42)

# %% [markdown]
# ### Model establishment

# %%
# from keras.models import Sequential
# from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
# from keras.layers import Activation, Dropout, Flatten, Dense

# def make_cnn_model():
#     model = Sequential()
#     model.add(Conv1D(64, 3, input_shape=x_train.shape[1:], padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(64, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
#     model.add(Conv1D(128, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(128, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
#     model.add(Conv1D(256, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(256, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(256, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Conv1D(512, 3, padding='same'))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
#     model.add(Flatten())
#     model.add(Dense(256))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(4096))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(num_targets, activation='linear'))
#     return model

# model = make_cnn_model()
# model.summary()
# # keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Complete & Train

# %%
# model.compile(optimizer='adam', loss='mse')

# callbacks = [
#             #  keras.callbacks.ModelCheckpoint("best_model.hdf5",
#             #                                  monitor="loss",
#             #                                  mode="min",
#             #                                  save_best_only=True),
#              keras.callbacks.EarlyStopping(monitor="val_loss",
#                                            mode="min",
#                                            verbose=1,
#                                            patience=10,
#                                            restore_best_weights=True), 
#              keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
#                                                factor=0.2,
#                                                patience=2,
#                                                min_lr=0.000001),
#             # keras.callbacks.TensorBoard(log_dir=os.path.join(HOST_path, "IDB_drilling_signal/outputs/R_logs"),
#             #                             histogram_freq=1,
#             #                             write_graph=True, 
#             #                             write_images=True),
#             ]

# history = model.fit(x_train, y_train,
#                     validation_split=0.2, 
#                     epochs=200, 
#                     batch_size=32, 
#                     # callbacks=callbacks, 
#                     shuffle=True)

# %% [markdown]
# ### Show model results

# %%
# y_test_true = y_test
# y_test_pred = model.predict(x_test)
# test_loss = model.evaluate(x_test, y_test)

# %% [markdown]
# ### Save model results

# %%
# eval_dict = {"y_test_true":y_test_true, "y_test_pred":y_test_pred, "test_loss":test_loss}

# model.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/R_model.hdf5"))
# np.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/R_history.npy"), history.history)
# np.save(os.path.join(HOST_path, "IDB_drilling_signal/outputs/R_evaluation.npy"), eval_dict)

# %% [markdown]
# ### Load model results

# %%
# from keras.models import load_model

# model = load_model("/home/svu/e1097232/IDB_drilling_signal/outputs/R_model.hdf5")
# hist = np.load("/home/svu/e1097232/IDB_drilling_signal/outputs/R_history.npy", allow_pickle=True)
# eval_dict = np.load("/home/svu/e1097232/IDB_drilling_signal/outputs/R_evaluation.npy", allow_pickle=True)

# %% [markdown]
# ### Plot model results

# %%
# # Plot Loss-Epoch
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model Loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train set', 'Test set'], loc='upper left')
# plt.savefig(os.path.join(HOST_path, "IDB_drilling_signal/outputs/R_loss.png"))
# plt.show()
